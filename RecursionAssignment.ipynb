# %%
# find the geometric sum i.e. 1 + 1/2 + 1/4 + 1/8 + ... + 1/(2^k) 

def geomentricSum(n):
    if n == 1:
        return 0
    print(n, geomentricSum(n-1))
    smallOut = 1/(2**geomentricSum(n-1))
    return 1 + smallOut

geomentricSum(3)
# Out:
# 2 0
# 3 2.0
# 2 0
# 1.25

# %%
def power(n):
    if n == 1:
        return 0
    smallOut = 2 ** power(n-1)
    return smallOut

power(3)
# Out:
# 2

# %%
# Find intersections in arrays -> O(nLog(n)) + O(mLog(m)) + O(n)

def getIntersection(A, B):
    # Sort the given array -> O(nLog(n))
    A = sorted(A)
    B = sorted(B)

    i = 0
    j = 0
    intersection = []
    while i < len(A) and j < len(B):
        if A[i] == B[j]:
            intersection.append(A[i])
            print(A[i])
            i += 1
            j += 1
        elif A[i] < B[j]:
            i += 1
        else:
            j += 1
            
arr1 = [1, 4, 6, 2, 0, 7, 5, 9]
arr2 = [0, 6, 2, 4, 22, 9, 7, 3]
getIntersection(arr1, arr2)
# Out:
# 0
# 2
# 4
# 6
# 7
# 9

# %% [markdown]
# ## Equilibrium Index

# %%
ls = [1, 2, 4, 8, 3, 2, 1, 1]

# navie solution
index = 1
while index < len(ls)-1:
    left = ls[:index]
    right = ls[index+1:]
    print(left, ls[index], right)
    if sum(left) == sum(right):
        print (ls[index])
        break
    index += 1
# Out:
# [1] 2 [4, 8, 3, 2, 1, 1]
# [1, 2] 4 [8, 3, 2, 1, 1]
# [1, 2, 4] 8 [3, 2, 1, 1]
# 8

# %%
# Solution 1

def get_equilibrium_index(ls):
    index = 1

    left_sum = sum(ls[:index])
    right_sum = sum(ls[index+1:])

    while index < len(ls)-1:
        if left_sum == right_sum:
            return index
        left_sum = left_sum + ls[index]
        right_sum = right_sum - ls[index+1]
        index += 1
    return -1

ls = [4, 0, 1, 1, 2]
get_equilibrium_index(ls)
# Out:
# 1

# %%
# Solution 2

def get_equilibrium_index(ls):
    index = 1
    
    total_sum = sum(ls)
    left_sum = sum(ls[:index])
    right_sum = total_sum - ls[index] - left_sum

    while index < len(ls)-1:
#         print(left_sum, right_sum)
        if left_sum == right_sum:
            return index
        left_sum = left_sum + ls[index]
        right_sum = right_sum - ls[index+1]
        index += 1
    return -1

ls = [4, 1, 1, 1, 0, -1]
get_equilibrium_index(ls)
# Out:
# -1

# %%
# Solution 3

# assume index to mid point of the array.
# ls[:mid] -> left || ls[mid+1:] -> right
# check left == right -> return index
# left < right -> move index to right by 1 position -> update 1) left + ls[index]   2) right - ls[index+1]
# left > right -> viz of above


def get_equilibrium_index(ls):
    index = len(ls)//2
    total_sum = sum(ls)
    print(index)

    while index != 0 and index != len(ls)-1:
        left_sum = sum(ls[:index])
        right_sum = total_sum - ls[index] - left_sum
#         print(index, left_sum, right_sum)
        
        if left_sum == right_sum:
            return index
        
        elif left_sum < right_sum:
            index += 1
        
        else:
            index -= 1
    return -1

ls = [1, 1, 0, 1, 1, 1, 0]
get_equilibrium_index(ls)
# Out:
# 3
# 3 2 2
# 3

# %% [markdown]
# ### Given an integer array of size 2N + 1. In this given array, N numbers are present twice and one number is present only once in the array. You need to find and return that number which is unique in the array.

 367 180 212 748 859 895 127 264 728 441 389 14 937 720 464 3 370 256 805 924 635 77 415 515 64 846 620 768 351 565 23 712 438 453 88 725 393 990 398 939 231 903 602 214 817 433 631 640 912 764 322 967 972 68 957 312 649 756 337 35 601 118 135 807 17 13 126 580 698 1 556 828 22 679 598 479 280 463 821 676 732 84 186 310 703 345 590 603 542 790 365 577 41 943 93 979 478 25 291 717 173 810 482 657 39 82 818 844 285 489 366 189 33 457 90 938 667 659 497 50 132 466 435 550 171 361 574 223 113 364 879 600 726 78 772 914 395 195 317 755 353 569 190 864 891 848 172 921 102 561 608 473 745 954 104 893 857 888 51 916 157 615 276 882 887 11 480 308 826 356 16 134 227 28 325 783 557 304 201 176 961 636 122 926 785 576 286 917 672 425 450 551 583 806 843 582 834 722 377 594 804 808 143 199 72 766 832 621 432 484 956 481 765 350 245 908 258 875 181 8 558 440 251 947 97 112 814 788 820 338 536 680 829 158 225 148 437 516 298 852 443 379 486 146 221 660 495 37 402 282 993 563 842 257 928 713 228 40 547 714 606 575 587 235 902 915 86 781 750 400 685 974 584 349 237 739 593 904 99 925 63 572 397 941 777 738 866 448 166 269 409 472 476 585 654 841 1000 307 759 216 955 596 795 872 374 523 170 512 861 900 645 467 597 987 831 975 390 105 128 800 5997 769 313 52 168 528 336 238 178 618 139 254 487 369 233 668 54 45 444 951 197 740 724 141 271 5 75 274 718 288 704 426 296 259 431 736 876 205 459 960 32 424 80 2 385 531 399 334 670 673 145 384 314 918 629 303 753 855 927 100 373 156 997 273 74 971 514 647 940 371 169 183 537 470 91 637 352 729 803 707 130 506 989 382 333 71 152 646 905 56 632 513 656 147 200 653 737 784 434 929 555 248 969 586 952 109 871 913 420 445 501 327 614 694 203 592 468 226 210 865 663 786 839 207 293 315 302 677 845 396 346 559 802 49 95 229 70 59 287 692 562 184 339 21 863 752 265 890 553 662 375 599 758 862 719 220 461 884 55 460 240 46 261 742 546 525 633 639 335 709 651 162 332 819 963 289 230 47 711 344 986 581 760 521 116 858 320 270 697 589 236 422 73 412 242 690 626 560 67 57 193 328 423 991 892 976 202 988 98 762 868 224 652 544 234 454 6 749 117 149 554 108 907 641 605 120 65 494 623 529 182 9 462 607 944 778 192 959 889 648 540 526 524 255 849 247 76 262 24 27 321 688 731 """
arr = [int(x) for x in arr.strip().split(' ')]

# %%
getUniqueNumber(arr)
# Out:
# 5997

# %% [markdown]
# ### Given an array of integers of size n which contains numbers from 0 to n - 2. Each number is present at least once. That is, if n = 5, numbers from 0 to 3 is present in the given array at least once and one number is present twice. You need to find and return that duplicate number present in the array.

# %%
# sum of n numbers (1, n) -> n*(n+1)/2
# sum of n-2 numbers -> (1, n-2) 

def find_duplicate(arr):
    n = len(arr) - 2 
    return int(sum(arr) - n*(n+1)/2)


ls = [0, 7, 2, 5, 4, 2, 1, 3, 6]
find_duplicate(ls)
# Out:
# 2

# %% [markdown]
# ## Pair Sum
# ### Given a random integer array A and a number x. Find and print the pair of elements in the array which sum to x. Array A can contain duplicate elements. While printing a pair, print the smaller element first. That is, if a valid pair is (6, 5) print "5 6". There is no constraint that out of 5 pairs which have to be printed in 1st line. You can print pairs in any order, just be careful about the order of elements in a pair.

# %%
ls = [int(x) for x in "48 11 2 16 26 7 44 29 14 5 34 23 47 43 49 36 36 6 39 43 26 44 25 17 3 18 45 4 38 10 19 10 45 32 18 44 30 14 5 36 23 28 34 15 36 22 50 30 14 22 32 25 36 1 8 48 14 32 9 34 15 31 18 32 4 3 15 17 44 48 10 39 15 15 48 7 3 11 39 21 28 35 17 38 16 42 48 6 18 49 40 19 35 10 22 14 37 32 3 19 50 32 9 19 45 42 40 28 9 40 42 19 43 42 41 19 50 10 10 15 33 49 41 9 32 13 36 11 13 50 50 46 17 39 1 22 30 39 16 16 2 8 24 43 38 7 48 15 29 39 21 13 4 22 18 45 50 33 43 16 28 25 6 20 47 10 15 36 19 33 6 14 12 24 19 18 34 39 5 41 7 27 9 33 20 25 23 4 49 32 40 28 39 2 44 9 38 18 1 27 32 17 6 11 16 6 25 44 34 31 3 14 15 11 48 49 18 5 47 8 19 2 40 17 7 47 11 14 47 14 31 37 7 23 32 17 15 48 12 20 21 12 13 42 38 15 14 26 27 25 35 43 15 32 37 12 3 7 44 14 35 18 21 49 9 9 39 26 17 45 39 39 24 14 6 30 6 47 16 42 42 12 10 40 49 46 26 41 34 34 47 30 3 33 4 7 6 7 1 16 39 34 37 34 45 4 40 43 48 22 23 20 50 10 7 20 45 43 47 47 19 15 27 44 8 18 21 8 3 41 2 43 17 41 4 47 45 18 49 41 3 41 14 16 23 1 24 2 9 6 31 5 35 25 50 36 34 26 29 45 39 47 44 5 34 1 8 7 48 17 10 13 5 31 38 27 22 36 32 21 11 27 16 5 31 30 6 35 20 47 15 23 50 14 11 20 5 31 12 15 1 4 5 36 16 2 38 10 12 28 1 12 22 34 19 1 37 13 31 20 16 26 21 34 40 31 3 12 28 19 49 3 5 2 12 42 33 12 32 12 45 9 32 3 30 38 28 16 7 8 2 4 34 31 42 41".split(" ")]
ls = sorted(ls)

# %%
x = 90
i = 0
while i < len(ls):
    j = i+1
    while j < len(ls):
        if ls[i] + ls[j] == x:
            print(ls[i], ls[j])
        j += 1
    i += 1
# Out:
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 40 50
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# 41 49
# ...

# %% [markdown]
# ## Triplet Sum
#
# ### Given a random integer array and a number x. Find and print the triplets of elements in the array which sum to x. While printing a triplet, print the smallest element first. That is, if a valid triplet is (6, 5, 10) print "5 6 10". There is no constraint that out of 5 triplets which have to be printed on 1st line. You can print triplets in any order, just be careful about the order of elements in a triplet.

# %%
ls = [1, 2, 3, 4, 5, 6, 7]
x =  12
i = 0
while i < len(ls):
    j = i+1
    while j < len(ls):
        k = j+1
        while k < len(ls):
            if ls[i] + ls[j] + ls[k] == x:
                print(ls[i], ls[j], ls[k])
            k += 1
        j += 1
    i += 1
# Out:
# 1 4 7
# 1 5 6
# 2 3 7
# 2 4 6
# 3 4 5

# %% [markdown]
# ## Rotate List
# ### You have been given a random integer array/list(ARR) of size N. Write a function that rotates the given array/list by D elements(towards the left).

# %%
ls = [1, 2, 3, 4, 5, 6, 7]
n = len(ls)

d = 2

print(ls[d:] + ls[:d])
# Out:
# [3, 4, 5, 6, 7, 1, 2]
